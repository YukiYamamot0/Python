# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
import pandas as pd
from matplotlib import pylab as plt
import seaborn as sns
# %matplotlib inline
sns.set()

#xdf3 = pd.read_excel('data/xdata3.xlsx')
#df4 = pd.read_excel('data/xdata4.xlsx')
#df5 = pd.read_excel('data/xdata5.xlsx')
#df6 = pd.read_excel('data/xdata6.xlsx')
#df3 = pd.read_excel('data/ydata3.xlsx')
#df4 = pd.read_excel('data/ydata4.xlsx')
#df5 = pd.read_excel('data/ydata5.xlsx')
#df6 = pd.read_excel('data/ydata6.xlsx')


#ts3 = xdf3['#data']
#ts3 = ydf3['#data']
#ts4 = xdf4['#data']
#ts4 = ydf4['#data']
#ts5 = xdf5['#data']
#ts5 = ydf5['#data']
#ts6 = xdf6['#data']
#ts6 = ydf6['#data']

xdf3 = pd.read_excel('xdata3.xlsx')
xdf4 = pd.read_excel('xdata4.xlsx')
xdf5 = pd.read_excel('xdata5.xlsx')
xdf6 = pd.read_excel('xdata6.xlsx')
ydf3 = pd.read_excel('ydata3.xlsx')
ydf4 = pd.read_excel('ydata4.xlsx')
ydf5 = pd.read_excel('ydata5.xlsx')
ydf6 = pd.read_excel('ydata6.xlsx')


xts3 = xdf3['#data']
yts3 = ydf3['#data']
xts4 = xdf4['#data']
yts4 = ydf4['#data']
xts5 = xdf5['#data']
yts5 = ydf5['#data']
xts6 = xdf6['#data']
yts6 = ydf6['#data']

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts3[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

# %%
predict=[]
for i in range(750,990):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)

# %%
plt.plot(yts3[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts3[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(50,250):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts3[50:250])
xdata = np.arange(50,250,1)
plt.plot(xdata, predict, 'r')

# %%
predict=[]
for i in range(750,990):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts3[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

# %%
predict=[]
for i in range(750,990):
    input = np.array(yts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    

plt.plot(yts3[760:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

# %%
m.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 1, 100)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 100)            80400
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 1)              101
# =================================================================
# Total params: 121,301
# Trainable params: 121,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
from scipy import stats

predict=[]
for i in range(0,100):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts3[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()

# %%
predict=[]
for i in range(0,100):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts3[i+10]-yhat) ** 2
    t = +s
    
e=t/100
print(e)
# Out:
# [4.6474855e-05]

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 900):
        tmpX = []
        for j in range(0, 50):
            tmpX.append(xts3[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(50, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts3[i:i+50]) 
    input = input.reshape(1,50,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts3[150:250])
xdata = np.arange(150,250,1)
plt.plot(xdata, predict, 'r')

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts3[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,3):
            tmpY.append(yts3[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(3))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts3[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts3[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-63f7677492d4> in <module>
#       4         tmpX = []
#       5         for j in range(0, 10):
# ----> 6             tmpX.append(xts3[i+j])
#       7         x.append(tmpX)
#       8
#
# NameError: name 'xts3' is not defined

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts4[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts4[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts4[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts4[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(0,100):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts4[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [3.3334502e-09]

# %%
predict=[]
for i in range(750,990):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts4[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

# %%
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts4[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts4[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts4[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts4[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')

fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts5[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts5[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(750,990):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    
plt.plot(yts5[750:1000])
xdata = np.arange(760,1000,1)
plt.plot(xdata, predict, 'r')
plt.show()

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 750):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts5[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts5[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts5[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts5[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)


for i in range(0,100):
    input = np.array(xts5[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts5[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()

# %%
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15132/3945230642.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.stem(xdata,predict, use_line_collection=True)
#       3 plt.show()
#
# D:\anakonda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anakonda\lib\site-packages\matplotlib\axes\_axes.py in stem(self, linefmt, markerfmt, basefmt, bottom, label, use_line_collection, orientation, *args)
#    2871                 linestyle = rcParams['lines.linestyle']
#    2872             xlines = self.vlines if orientation == "vertical" else self.hlines
# -> 2873             stemlines = xlines(
#    2874                 locs, bottom, heads,
#    2875                 colors=linecolor, linestyles=linestyle, label="_nolegend_")
#
# D:\anakonda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\anakonda\lib\site-packages\matplotlib\axes\_axes.py in vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1113         masked_verts[:, 0, 1] = ymin
#    1114         masked_verts[:, 1, 0] = x
# -> 1115         masked_verts[:, 1, 1] = ymax
#    1116
#    1117         lines = mcoll.LineCollection(masked_verts, colors=colors,
#
# ~\AppData\Roaming\Python\Python38\site-packages\numpy\ma\core.py in __setitem__(self, indx, value)
#    3378         if _mask is nomask:
#    3379             # Set the data, then the mask
# -> 3380             _data[indx] = dval
#    3381             if mval is not nomask:
#    3382                 _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# ValueError: could not broadcast input array from shape (200) into shape (100)

# %%
x = [] # train
y = [] # test (answer)

# %%
plt.plot(yts5[100:200])
xdata = np.arange(100,200,1)
plt.plot(xdata, predict, 'r')

# %%
x = [] # train
y = [] # test (answer)
for i in range(0, 980):
        tmpX = []
        for j in range(0, 10):
            tmpX.append(xts6[i+j])
        x.append(tmpX)
            
        tmpY = []
        for j in range(0,1):
            tmpY.append(yts6[10+j+i])
        y.append(tmpY)
    

x = np.array(x)
y = np.array(y)
x = x.reshape((x.shape[0], x.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))


m = Sequential()
#100は分かりやすいよう。
m.add(LSTM(100, activation='relu', input_shape=(10, 1)))
m.add(RepeatVector(1))
m.add(LSTM(100, activation='relu', return_sequences=True))
m.add(TimeDistributed(Dense(1)))
m.compile(optimizer='adam', loss='mse')
m.fit(x, y, epochs=1000, verbose=0)

predict=[]
for i in range(0,100):
    input = np.array(xts6[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    predict.append(yhat)
    s=(yts6[i+10]-yhat) ** 2
    t = +s
    
plt.plot(yts6[10:110])
xdata = np.arange(10,110,1)
plt.plot(xdata, predict, 'r')

e=t/100
print(e)

predict=[]
for i in range(0,100):
    input = np.array(xts6[i:i+10]) 
    input = input.reshape(1,10,1)
    yhat = m.predict(input)
    yhat = yhat.ravel()
    yhat = yhat - yts6[i+10]
    predict.append(yhat)
    
    
fig, ax = plt.subplots()
ax.stem(xdata,predict, use_line_collection=True)
plt.show()
# Out:
# [2.0132702e-06]
